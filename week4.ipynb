# %%
# !pip install scapy

from scapy.all import *

# 构造ICMP数据包
packet = IP(dst='10.240.5.13')/ICMP()

# 发送并等待回复（timeout=1秒）
ans, unans = sr(packet, timeout=1)

packet.summary()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.2 MB/s eta 0:00:00a 0:00:01
# ...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 9
#       6 packet = IP(dst='10.240.5.13')/ICMP()
#       8 # 发送并等待回复（timeout=1秒）
# ----> 9 ans, unans = sr(packet, timeout=1)
#      11 packet.summary()
#
# File /opt/conda/lib/python3.11/site-packages/scapy/sendrecv.py:706, in sr(x, promisc, filter, nofilter, *args, **kargs)
#     704     del kargs["iface"]
#     705 iface, ipv6 = _interface_selection(x)
# --> 706 s = iface.l3socket(ipv6)(
#     707     promisc=promisc, filter=filter,
#     708     iface=iface, nofilter=nofilter,
#     709 )
#     710 result = sndrcv(s, x, *args, **kargs)
#     711 s.close()
#
# File /opt/conda/lib/python3.11/site-packages/scapy/arch/linux/__init__.py:327, in L3PacketSocket.__init__(self, iface, type, promisc, filter, nofilter, monitor)
# ...

# %%
rdpcap("library-um.pcapng")

# %%
# Out:
# /bin/bash: line 1: ping: command not found

# %%
ether_broadcast = Ether(dst='ff:ff:ff:ff:ff:ff')

# %%
arp_header = ARP(pdst-10.160.37.0/28)
# Out:
#   Cell In[7], line 1
#     arp_header = ARP(pdst-10.160.37.0/28)
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
ans,unans = srp(ether_broadcast/arp_header,timeout=2)
